# %% [markdown]
# # Micro Credit Loan  Detection Using Machine Laerning Classifier

# %%
# Load Labraries:-
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from dateutil import parser

# %%
# Data Load
df= pd.read_csv(r'D:\\data_file.csv')
df
# Out:
#         Unnamed: 0  label       msisdn     aon  daily_decr30  daily_decr90  \
# 0                1      0  21408I70789   272.0   3055.050000   3065.150000
# 1                2      1  76462I70374   712.0  12122.000000  12124.750000
# 2                3      1  17943I70372   535.0   1398.000000   1398.000000
# 3                4      1  55773I70781   241.0     21.228000     21.228000
# 4                5      1  03813I82730   947.0    150.619333    150.619333
# ...            ...    ...          ...     ...           ...           ...
# 209588      209589      1  22758I85348   404.0    151.872333    151.872333
# 209589      209590      1  95583I84455  1075.0     36.936000     36.936000
# 209590      209591      1  28556I85350  1013.0  11843.111667  11904.350000
# 209591      209592      1  59712I82733  1732.0  12488.228333  12574.370000
# 209592      209593      1  65061I85339  1581.0   4489.362000   4534.820000
#
# ...

# %%
df.tail()
# Out:
#         Unnamed: 0  label       msisdn     aon  daily_decr30  daily_decr90  \
# 209588      209589      1  22758I85348   404.0    151.872333    151.872333
# 209589      209590      1  95583I84455  1075.0     36.936000     36.936000
# 209590      209591      1  28556I85350  1013.0  11843.111667  11904.350000
# 209591      209592      1  59712I82733  1732.0  12488.228333  12574.370000
# 209592      209593      1  65061I85339  1581.0   4489.362000   4534.820000
#
#         rental30  rental90  last_rech_date_ma  last_rech_date_da  ...  \
# 209588   1089.19   1089.19                1.0                0.0  ...
# 209589   1728.36   1728.36                4.0                0.0  ...
# 209590   5861.83   8893.20                3.0                0.0  ...
# 209591    411.83    984.58                2.0               38.0  ...
# 209592    483.92    631.20               13.0                0.0  ...
#
#         maxamnt_loans30  medianamnt_loans30  cnt_loans90  amnt_loans90  \
# ...

# %%
pd.options.display.max_rows
pd.options.display.max_columns
df
# Out:
#         Unnamed: 0  label       msisdn     aon  daily_decr30  daily_decr90  \
# 0                1      0  21408I70789   272.0   3055.050000   3065.150000
# 1                2      1  76462I70374   712.0  12122.000000  12124.750000
# 2                3      1  17943I70372   535.0   1398.000000   1398.000000
# 3                4      1  55773I70781   241.0     21.228000     21.228000
# 4                5      1  03813I82730   947.0    150.619333    150.619333
# ...            ...    ...          ...     ...           ...           ...
# 209588      209589      1  22758I85348   404.0    151.872333    151.872333
# 209589      209590      1  95583I84455  1075.0     36.936000     36.936000
# 209590      209591      1  28556I85350  1013.0  11843.111667  11904.350000
# 209591      209592      1  59712I82733  1732.0  12488.228333  12574.370000
# 209592      209593      1  65061I85339  1581.0   4489.362000   4534.820000
#
#         rental30  rental90  last_rech_date_ma  last_rech_date_da  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209593 entries, 0 to 209592
# Data columns (total 37 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Unnamed: 0            209593 non-null  int64
#  1   label                 209593 non-null  int64
#  2   msisdn                209593 non-null  object
#  3   aon                   209593 non-null  float64
#  4   daily_decr30          209593 non-null  float64
#  5   daily_decr90          209593 non-null  float64
#  6   rental30              209593 non-null  float64
#  7   rental90              209593 non-null  float64
#  8   last_rech_date_ma     209593 non-null  float64
#  9   last_rech_date_da     209593 non-null  float64
#  10  last_rech_amt_ma      209593 non-null  int64
#  11  cnt_ma_rech30         209593 non-null  int64
#  12  fr_ma_rech30          209593 non-null  float64
#  13  sumamnt_ma_rech30     209593 non-null  float64
# ...

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#           Unnamed: 0          label            aon   daily_decr30  \
# count  209593.000000  209593.000000  209593.000000  209593.000000
# mean   104797.000000       0.875177    8112.343445    5381.402289
# std     60504.431823       0.330519   75696.082531    9220.623400
# min         1.000000       0.000000     -48.000000     -93.012667
# 25%     52399.000000       1.000000     246.000000      42.440000
# 50%    104797.000000       1.000000     527.000000    1469.175667
# 75%    157195.000000       1.000000     982.000000    7244.000000
# max    209593.000000       1.000000  999860.755168  265926.000000
#
#         daily_decr90       rental30       rental90  last_rech_date_ma  \
# count  209593.000000  209593.000000  209593.000000      209593.000000
# mean     6082.515068    2692.581910    3483.406534        3755.847800
# std     10918.812767    4308.586781    5770.461279       53905.892230
# min       -93.012667  -23737.140000  -24720.580000         -29.000000
# ...

# %% [markdown]
# # Data Visualization

# %%
# pariplot of micro credit loan dataframe
sns.pairplot(df, hue= 'label')

# %%
# pair plot of sample feature
sns.pairplot(df, hue = 'label', 
             vars = ['aon','daily_decr30','daily_decr90','rental30','rental90','last_rech_date_ma','last_rech_date_da','last_rech_amt_ma','payback30','payback90',
'cnt_loans30'

,'amnt_loans30',

'maxamnt_loans30',

'medianamnt_loans30',

'cnt_loans90',

'amnt_loans90',

'maxamnt_loans90'
] )

# %%
 #Count the target class
sns.countplot(df['label'])
# Out:
# D:\New folder\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='label', ylabel='count'>

# %%
# counter plot of feature 'payback30'
plt.figure(figsize = (20,8))
sns.countplot(df['payback30'])
# Out:
# D:\New folder\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='payback30', ylabel='count'>

# %%
# counter plot of feature 'payback90'
plt.figure(figsize = (20,8))
sns.countplot(df['payback90'])
# Out:
# D:\New folder\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='payback90', ylabel='count'>

# %%
df2=df.drop(['pcircle','pdate','msisdn'], axis=1 )
df2
# Out:
#         Unnamed: 0  label     aon  daily_decr30  daily_decr90  rental30  \
# 0                1      0   272.0   3055.050000   3065.150000    220.13
# 1                2      1   712.0  12122.000000  12124.750000   3691.26
# 2                3      1   535.0   1398.000000   1398.000000    900.13
# 3                4      1   241.0     21.228000     21.228000    159.42
# 4                5      1   947.0    150.619333    150.619333   1098.90
# ...            ...    ...     ...           ...           ...       ...
# 209588      209589      1   404.0    151.872333    151.872333   1089.19
# 209589      209590      1  1075.0     36.936000     36.936000   1728.36
# 209590      209591      1  1013.0  11843.111667  11904.350000   5861.83
# 209591      209592      1  1732.0  12488.228333  12574.370000    411.83
# 209592      209593      1  1581.0   4489.362000   4534.820000    483.92
#
#         rental90  last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  ...  \
# ...

# %%
# heatmap of DataFrame
plt.figure(figsize=(16,9))
sns.heatmap(df2)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-42-ca100f9383dd> in <module>
#       1 # heatmap of DataFrame
#       2 plt.figure(figsize=(16,9))
# ----> 3 sns.heatmap(df2)
#
# D:\New folder\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# D:\New folder\lib\site-packages\seaborn\matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     556     if square:
#     557         ax.set_aspect("equal")
# --> 558     plotter.plot(ax, cbar_ax, kwargs)
#     559     return ax
#     560
#
# ...

# %% [markdown]
# # Heatmap of a correlation matrix

# %%
# Heatmap of Correlation matrix of Micro Credit Loan DataFrame
plt.figure(figsize=(16,9))
sns.heatmap(df2.corr(), annot = True, cmap ='coolwarm', linewidths=2)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Data Preprocessing
# Split DataFrame in train and test

# %%
# input variable
X = df2.drop(['label'], axis = 1)
X.head(6)
# Out:
#    Unnamed: 0    aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0           1  272.0   3055.050000   3065.150000    220.13    260.13
# 1           2  712.0  12122.000000  12124.750000   3691.26   3691.26
# 2           3  535.0   1398.000000   1398.000000    900.13    900.13
# 3           4  241.0     21.228000     21.228000    159.42    159.42
# 4           5  947.0    150.619333    150.619333   1098.90   1098.90
# 5           6  568.0   2257.362667   2261.460000    368.13    380.13
#
#    last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  ...  \
# 0                2.0                0.0              1539              2  ...
# 1               20.0                0.0              5787              1  ...
# 2                3.0                0.0              1539              1  ...
# 3               41.0                0.0               947              0  ...
# 4                4.0                0.0              2309              7  ...
# ...

# %%
# output variable
y = df2['label']
y.head(6)
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    1
# 5    1
# Name: label, dtype: int64

# %%
# split dataset into train and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state= 5)

# %% [markdown]
# # Feature Scaling

# %%
# Feature scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train_sc = sc.fit_transform(X_train)
X_test_sc = sc.transform(X_test)

# %% [markdown]
# # Micro Credit Loan Detection Machine Learning Model Building

# %%
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score

# %% [markdown]
# # Support Vector Classifier

# %%
# Support vector classifier
from sklearn.svm import SVC
svc_classifier = SVC()
svc_classifier.fit(X_train, y_train)
y_pred_scv = svc_classifier.predict(X_test)
accuracy_score(y_test, y_pred_scv)
# Out:
# 0.8737565304515852

# %%
# Train with Standard scaled Data
svc_classifier2 = SVC()
svc_classifier2.fit(X_train_sc, y_train)
y_pred_svc_sc = svc_classifier2.predict(X_test_sc)
accuracy_score(y_test, y_pred_svc_sc)
# Out:
# 0.8754741286767337

# %% [markdown]
# # Logistic Regression

# %%
# Logistic Regression
from sklearn.linear_model import LogisticRegression
lr_classifier = LogisticRegression(random_state = 51, penalty = 'l2')
lr_classifier.fit(X_train, y_train)
y_pred_lr = lr_classifier.predict(X_test)
accuracy_score(y_test, y_pred_lr)
# Out:
# D:\New folder\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.8748538848732078

# %%
# Train with Standard scaled Data
lr_classifier2 = LogisticRegression(random_state = 51, penalty = 'l2')
lr_classifier2.fit(X_train_sc, y_train)
y_pred_lr_sc = lr_classifier.predict(X_test_sc)
accuracy_score(y_test, y_pred_lr_sc)
# Out:
# D:\New folder\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.47331758868293616

# %% [markdown]
# # K – Nearest Neighbor Classifier

# %%
# K – Nearest Neighbor Classifier
from sklearn.neighbors import KNeighborsClassifier
knn_classifier = KNeighborsClassifier(n_neighbors = 5, metric = 'minkowski', p = 2)
knn_classifier.fit(X_train, y_train)
y_pred_knn = knn_classifier.predict(X_test)
accuracy_score(y_test, y_pred_knn)
# Out:
# 0.8653832391039863

# %%
# Train with Standard scaled Data
knn_classifier2 = KNeighborsClassifier(n_neighbors = 5, metric = 'minkowski', p = 2)
knn_classifier2.fit(X_train_sc, y_train)
y_pred_knn_sc = knn_classifier.predict(X_test_sc)
accuracy_score(y_test, y_pred_knn_sc)
# Out:
# 0.8737565304515852

# %% [markdown]
# # Naive Bayes Classifier

# %%
# Naive Bayes Classifier
from sklearn.naive_bayes import GaussianNB
nb_classifier = GaussianNB()
nb_classifier.fit(X_train, y_train)
y_pred_nb = nb_classifier.predict(X_test)
accuracy_score(y_test, y_pred_nb)
# Out:
# 0.5522316849161478

# %%
# Train with Standard scaled Data
nb_classifier2 = GaussianNB()
nb_classifier2.fit(X_train_sc, y_train)
y_pred_nb_sc = nb_classifier2.predict(X_test_sc)
accuracy_score(y_test, y_pred_nb_sc)
# Out:
# 0.5825759202271047

# %% [markdown]
# # Decision Tree Classifier

# %%
# Decision Tree Classifier
from sklearn.tree import DecisionTreeClassifier
dt_classifier = DecisionTreeClassifier(criterion = 'entropy', random_state = 51)
dt_classifier.fit(X_train, y_train)
y_pred_dt = dt_classifier.predict(X_test)
accuracy_score(y_test, y_pred_dt)
# Out:
# 0.868699157899759

# %%
# Train with Standard scaled Data
dt_classifier2 = DecisionTreeClassifier(criterion = 'entropy', random_state = 51)
dt_classifier2.fit(X_train_sc, y_train)
y_pred_dt_sc = dt_classifier.predict(X_test_sc)
accuracy_score(y_test, y_pred_dt_sc)
# Out:
# 0.6843197595362485

# %% [markdown]
# # Confusion Matrix

# %%
cm = confusion_matrix(y_test, y_pred_dt_sc)
plt.title('Heatmap of Confusion Matrix', fontsize = 15)
sns.heatmap(cm, annot = True)
plt.show()

# %% [markdown]
# # Classification Report of Model

# %%
print(classification_report(y_test, y_pred_dt_sc))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.02      0.03      0.03      5292
#            1       0.85      0.78      0.81     36627
#
#     accuracy                           0.68     41919
#    macro avg       0.43      0.41      0.42     41919
# weighted avg       0.74      0.68      0.71     41919

# %% [markdown]
# # Cross-validation of the ML model
# To find the ML model is overfitted, under fitted or generalize doing cross-validation.

# %%
# Cross validation
from sklearn.model_selection import cross_val_score
cross_validation = cross_val_score(estimator = dt_classifier, X = X_train_sc, y = y_train, cv = 10)
print("Cross validation of Dic model = ",cross_validation)
print("Cross validation of Dic model (in mean) = ",cross_validation.mean())
from sklearn.model_selection import cross_val_score
cross_validation = cross_val_score(estimator = dt_classifier, X = X_train_sc,y = y_train, cv = 10)
print("Cross validation accuracy of Dic model = ", cross_validation)
print("\nCross validation mean accuracy of Dic model = ", cross_validation.mean())
# Out:
# Cross validation of Dic model =  [0.87243559 0.86969227 0.86569656 0.8671875  0.86920737 0.86926701
#  0.87284547 0.87218942 0.86873024 0.86628496]
# Cross validation of Dic model (in mean) =  0.8693536410095575
# Cross validation accuracy of Dic model =  [0.87243559 0.86969227 0.86569656 0.8671875  0.86920737 0.86926701
#  0.87284547 0.87218942 0.86873024 0.86628496]
#
# Cross validation mean accuracy of Dic model =  0.8693536410095575

# %%
print('Thank_you')
# Out:
# Thank_you
